# %% [markdown]
# # 일반음식점 인허가 정보

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw_data_일반음식점 csv 경로",encoding="cp949", low_memory=False)

# %%
df.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수',
#        '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수', '건물소유구분명', '보증액', '월세액',
#        '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지', 'Unnamed: 47'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호       인허가일자  \
# 0   1  일반음식점  07_24_04_P   5710000  5730000-101-2023-00460  2023-11-20
# 1   2  일반음식점  07_24_04_P   4060000  4060000-101-2023-00770  2023-11-15
# 2   3  일반음식점  07_24_04_P   4301000  4301000-101-2023-00144  2023-11-15
# 3   4  일반음식점  07_24_04_P   4301000  4301000-101-2023-00143  2023-11-15
# 4   5  일반음식점  07_24_04_P   3930000  5560000-101-2023-00271  2023-09-22
# 5   6  일반음식점  07_24_04_P   5590000  5590000-101-2023-00345  2023-11-27
# 6   7  일반음식점  07_24_04_P   5590000  5590000-101-2023-00344  2023-11-27
# 7   8  일반음식점  07_24_04_P   3910000  3910029-101-2023-00449  2023-11-27
# 8   9  일반음식점  07_24_04_P   5530000  5530000-101-2023-01536  2023-11-27
# 9  10  일반음식점  07_24_04_P   5530000  5530000-101-2023-01533  2023-11-27
#
#    인허가취소일자  영업상태구분코드 영업상태명  상세영업상태코드  ... 공장생산직직원수 건물소유구분명  보증액  월세액  \
# 0      NaN         3    폐업         2  ...      0.0     NaN  0.0    0
# ...

# %%
df = df.drop(columns={'개방서비스아이디', '개방자치단체코드', '관리번호','좌표정보(x)', '좌표정보(y)',
       '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수',
       '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수', '건물소유구분명', '보증액', '월세액',
       '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지', 'Unnamed: 47'})

# %%
df
# Out:
#               번호 개방서비스명       인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  \
# 0              1  일반음식점  2023-11-20      NaN         3     폐업         2
# 1              2  일반음식점  2023-11-15      NaN         3     폐업         2
# 2              3  일반음식점  2023-11-15      NaN         3     폐업         2
# 3              4  일반음식점  2023-11-15      NaN         3     폐업         2
# 4              5  일반음식점  2023-09-22      NaN         3     폐업         2
# ...          ...    ...         ...      ...       ...    ...       ...
# 2126897  2126898  일반음식점  1995-09-01      NaN         1  영업/정상         1
# 2126898  2126899  일반음식점  2012-01-19      NaN         1  영업/정상         1
# 2126899  2126900  일반음식점  2014-06-12      NaN         1  영업/정상         1
# 2126900  2126901  일반음식점  2014-03-21      NaN         1  영업/정상         1
# 2126901  2126902  일반음식점  2014-03-19      NaN         1  영업/정상         1
#
#         상세영업상태명        폐업일자  휴업시작일자  ...   소재지면적  소재지우편번호  \
# ...

# %%
df = df.drop(columns={'상세영업상태코드','상세영업상태명','사업장명','최종수정시점','데이터갱신구분','데이터갱신일자'})

# %%
df
# Out:
#               번호 개방서비스명       인허가일자  인허가취소일자  영업상태구분코드  영업상태명        폐업일자  \
# 0              1  일반음식점  2023-11-20      NaN         3     폐업  2023-12-19
# 1              2  일반음식점  2023-11-15      NaN         3     폐업  2023-11-26
# 2              3  일반음식점  2023-11-15      NaN         3     폐업  2023-11-18
# 3              4  일반음식점  2023-11-15      NaN         3     폐업  2023-11-18
# 4              5  일반음식점  2023-09-22      NaN         3     폐업  2023-10-17
# ...          ...    ...         ...      ...       ...    ...         ...
# 2126897  2126898  일반음식점  1995-09-01      NaN         1  영업/정상         NaN
# 2126898  2126899  일반음식점  2012-01-19      NaN         1  영업/정상         NaN
# 2126899  2126900  일반음식점  2014-06-12      NaN         1  영업/정상         NaN
# 2126900  2126901  일반음식점  2014-03-21      NaN         1  영업/정상         NaN
# 2126901  2126902  일반음식점  2014-03-19      NaN         1  영업/정상         NaN
#
#          휴업시작일자  휴업종료일자  재개업일자         소재지전화   소재지면적  소재지우편번호  \
# ...

# %%
df['재개업일자'].value_counts()
# Out:
# Series([], Name: 재개업일자, dtype: int64)

# %%
df['업태구분명'].value_counts()
# Out:
# 한식                  975727
# 기타                  234131
# 호프/통닭               203396
# 분식                  179815
# 경양식                 120755
# 식육(숯불구이)             69629
# 중국식                  68896
# 통닭(치킨)               54954
# 일식                   52788
# 정종/대포집/소주방           44167
# 횟집                   31193
# 까페                   22118
# 패스트푸드                18716
# 뷔페식                  10476
# 탕류(보신용)              10042
# 김밥(도시락)               9170
# 외국음식전문점(인도,태국등)       8339
# 전통찻집                  2277
# 라이브카페                 1731
# 패밀리레스트랑               1622
# 냉면집                   1491
# 복어취급                  1436
# 감성주점                  1167
# 출장조리                  1139
# 이동조리                   904
# 키즈카페                   640
# 일반조리판매                   9
# 기타 휴게음식점                 8
# 커피숍                      5
# 간이주점                     4
# 다방                       2
# 193959.150482967         1
# 식품소분업                    1
# 제과점영업                    1
# ...

# %%
df['개방서비스명'].value_counts()
# Out:
# 일반음식점    2126902
# Name: 개방서비스명, dtype: int64

# %%
df = df.drop(columns={'개방서비스명'})

# %%
df
# Out:
#               번호       인허가일자  인허가취소일자  영업상태구분코드  영업상태명        폐업일자  휴업시작일자  \
# 0              1  2023-11-20      NaN         3     폐업  2023-12-19     NaN
# 1              2  2023-11-15      NaN         3     폐업  2023-11-26     NaN
# 2              3  2023-11-15      NaN         3     폐업  2023-11-18     NaN
# 3              4  2023-11-15      NaN         3     폐업  2023-11-18     NaN
# 4              5  2023-09-22      NaN         3     폐업  2023-10-17     NaN
# ...          ...         ...      ...       ...    ...         ...     ...
# 2126897  2126898  1995-09-01      NaN         1  영업/정상         NaN     NaN
# 2126898  2126899  2012-01-19      NaN         1  영업/정상         NaN     NaN
# 2126899  2126900  2014-06-12      NaN         1  영업/정상         NaN     NaN
# 2126900  2126901  2014-03-21      NaN         1  영업/정상         NaN     NaN
# 2126901  2126902  2014-03-19      NaN         1  영업/정상         NaN     NaN
#
#          휴업종료일자  재개업일자         소재지전화   소재지면적  소재지우편번호  \
# ...

# %%
df['도로명전체주소'].isna().sum()
# Out:
# 829270

# %%
df['소재지전체주소'].isna().sum()
# Out:
# 4069

# %%
df2 = df.dropna(subset=['소재지전체주소'])

# %%
df2['소재지전체주소'].isna().sum()
# Out:
# 0

# %%
df2 = df2.drop(columns={'소재지전화','소재지우편번호','도로명전체주소'})

# %%
df2
# Out:
#               번호       인허가일자  인허가취소일자  영업상태구분코드  영업상태명        폐업일자  휴업시작일자  \
# 0              1  2023-11-20      NaN         3     폐업  2023-12-19     NaN
# 1              2  2023-11-15      NaN         3     폐업  2023-11-26     NaN
# 2              3  2023-11-15      NaN         3     폐업  2023-11-18     NaN
# 3              4  2023-11-15      NaN         3     폐업  2023-11-18     NaN
# 4              5  2023-09-22      NaN         3     폐업  2023-10-17     NaN
# ...          ...         ...      ...       ...    ...         ...     ...
# 2126897  2126898  1995-09-01      NaN         1  영업/정상         NaN     NaN
# 2126898  2126899  2012-01-19      NaN         1  영업/정상         NaN     NaN
# 2126899  2126900  2014-06-12      NaN         1  영업/정상         NaN     NaN
# 2126900  2126901  2014-03-21      NaN         1  영업/정상         NaN     NaN
# 2126901  2126902  2014-03-19      NaN         1  영업/정상         NaN     NaN
#
# ...

# %%
seoul_df = df2[df2['소재지전체주소'].str.contains('서울특별시')]

# %%
seoul_df = seoul_df.drop(columns={'번호','인허가취소일자','휴업시작일자','휴업종료일자','재개업일자'})

# %%
seoul_df
# Out:
#               인허가일자  영업상태구분코드  영업상태명        폐업일자   소재지면적  \
# 11       2023-12-01         3     폐업  2024-01-14    3.30
# 16       2023-09-22         3     폐업  2024-01-17   14.38
# 17       2023-11-27         3     폐업  2023-12-06     NaN
# 19       2023-12-01         3     폐업  2023-12-08   46.20
# 30       2023-11-27         3     폐업  2024-02-14   10.00
# ...             ...       ...    ...         ...     ...
# 2098071  2020-08-03         1  영업/정상         NaN   59.17
# 2098072  2020-08-03         1  영업/정상         NaN   63.44
# 2098073  2020-08-03         1  영업/정상         NaN   40.00
# 2098198  2020-08-03         1  영업/정상         NaN  112.91
# 2099441  2020-08-03         1  영업/정상         NaN   50.37
#
#                                   소재지전체주소  도로명우편번호 업태구분명
# 11       서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점   2555.0    기타
# 16        서울특별시 강남구 논현동 221-7 한양수자인 어반게이트   6107.0    한식
# 17               서울특별시 서초구 반포동 19-3 센트럴시티   6546.0    기타
# ...

# %%
seoul_df  = seoul_df.drop(columns={'소재지면적','도로명우편번호'})

# %%
seoul_df
# Out:
#               인허가일자  영업상태구분코드  영업상태명        폐업일자  \
# 11       2023-12-01         3     폐업  2024-01-14
# 16       2023-09-22         3     폐업  2024-01-17
# 17       2023-11-27         3     폐업  2023-12-06
# 19       2023-12-01         3     폐업  2023-12-08
# 30       2023-11-27         3     폐업  2024-02-14
# ...             ...       ...    ...         ...
# 2098071  2020-08-03         1  영업/정상         NaN
# 2098072  2020-08-03         1  영업/정상         NaN
# 2098073  2020-08-03         1  영업/정상         NaN
# 2098198  2020-08-03         1  영업/정상         NaN
# 2099441  2020-08-03         1  영업/정상         NaN
#
#                                   소재지전체주소 업태구분명
# 11       서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타
# 16        서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식
# 17               서울특별시 서초구 반포동 19-3 센트럴시티    기타
# 19              서울특별시 강남구 대치동 889-65 우영빌딩    일식
# 30                서울특별시 강동구 천호동 572 현대백화점    기타
# ...                                   ...   ...
# ...

# %%
seoul_df['인허가일자'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 501901 entries, 11 to 2099441
# Series name: 인허가일자
# Non-Null Count   Dtype
# --------------   -----
# 501901 non-null  object
# dtypes: object(1)
# memory usage: 7.7+ MB

# %%
seoul_df['폐업일자'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 501901 entries, 11 to 2099441
# Series name: 폐업일자
# Non-Null Count   Dtype
# --------------   -----
# 376577 non-null  object
# dtypes: object(1)
# memory usage: 7.7+ MB

# %%
# '인허가일자' 열을 datetime 형식으로 변환
seoul_df['인허가일자'] = pd.to_datetime(seoul_df['인허가일자'])
seoul_df
# Out:
#              인허가일자  영업상태구분코드  영업상태명        폐업일자  \
# 11      2023-12-01         3     폐업  2024-01-14
# 16      2023-09-22         3     폐업  2024-01-17
# 17      2023-11-27         3     폐업  2023-12-06
# 19      2023-12-01         3     폐업  2023-12-08
# 30      2023-11-27         3     폐업  2024-02-14
# ...            ...       ...    ...         ...
# 2098071 2020-08-03         1  영업/정상         NaN
# 2098072 2020-08-03         1  영업/정상         NaN
# 2098073 2020-08-03         1  영업/정상         NaN
# 2098198 2020-08-03         1  영업/정상         NaN
# 2099441 2020-08-03         1  영업/정상         NaN
#
#                                   소재지전체주소 업태구분명
# 11       서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타
# 16        서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식
# 17               서울특별시 서초구 반포동 19-3 센트럴시티    기타
# 19              서울특별시 강남구 대치동 889-65 우영빌딩    일식
# 30                서울특별시 강동구 천호동 572 현대백화점    기타
# ...                                   ...   ...
# ...

# %%
seoul_df['인허가일자'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 501901 entries, 11 to 2099441
# Series name: 인허가일자
# Non-Null Count   Dtype
# --------------   -----
# 501901 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.7 MB

# %%
# '년'과 '월' 열 추가
seoul_df['인허가_년'] = seoul_df['인허가일자'].dt.year
seoul_df['인허가_월'] = seoul_df['인허가일자'].dt.month

# %%
seoul_df
# Out:
#              인허가일자  영업상태구분코드  영업상태명        폐업일자  \
# 11      2023-12-01         3     폐업  2024-01-14
# 16      2023-09-22         3     폐업  2024-01-17
# 17      2023-11-27         3     폐업  2023-12-06
# 19      2023-12-01         3     폐업  2023-12-08
# 30      2023-11-27         3     폐업  2024-02-14
# ...            ...       ...    ...         ...
# 2098071 2020-08-03         1  영업/정상         NaN
# 2098072 2020-08-03         1  영업/정상         NaN
# 2098073 2020-08-03         1  영업/정상         NaN
# 2098198 2020-08-03         1  영업/정상         NaN
# 2099441 2020-08-03         1  영업/정상         NaN
#
#                                   소재지전체주소 업태구분명  인허가_년  인허가_월
# 11       서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타   2023     12
# 16        서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식   2023      9
# 17               서울특별시 서초구 반포동 19-3 센트럴시티    기타   2023     11
# 19              서울특별시 강남구 대치동 889-65 우영빌딩    일식   2023     12
# 30                서울특별시 강동구 천호동 572 현대백화점    기타   2023     11
# ...

# %%
# '폐업일자' 열을 datetime 형식으로 변환
seoul_df['폐업일자'] = pd.to_datetime(seoul_df['폐업일자'])
# '년'과 '월' 열 추가
seoul_df['폐업_년'] = seoul_df['폐업일자'].dt.year
seoul_df['폐업_월'] = seoul_df['폐업일자'].dt.month

# %%
seoul_df
# Out:
#              인허가일자  영업상태구분코드  영업상태명       폐업일자  \
# 11      2023-12-01         3     폐업 2024-01-14
# 16      2023-09-22         3     폐업 2024-01-17
# 17      2023-11-27         3     폐업 2023-12-06
# 19      2023-12-01         3     폐업 2023-12-08
# 30      2023-11-27         3     폐업 2024-02-14
# ...            ...       ...    ...        ...
# 2098071 2020-08-03         1  영업/정상        NaT
# 2098072 2020-08-03         1  영업/정상        NaT
# 2098073 2020-08-03         1  영업/정상        NaT
# 2098198 2020-08-03         1  영업/정상        NaT
# 2099441 2020-08-03         1  영업/정상        NaT
#
#                                   소재지전체주소 업태구분명  인허가_년  인허가_월    폐업_년  폐업_월
# 11       서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타   2023     12  2024.0   1.0
# 16        서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식   2023      9  2024.0   1.0
# 17               서울특별시 서초구 반포동 19-3 센트럴시티    기타   2023     11  2023.0  12.0
# 19              서울특별시 강남구 대치동 889-65 우영빌딩    일식   2023     12  2023.0  12.0
# ...

# %%
seoul_df = seoul_df.drop(columns={'인허가일자','폐업일자'})

# %%
seoul_df
# Out:
#          영업상태구분코드  영업상태명                           소재지전체주소 업태구분명  인허가_년  \
# 11              3     폐업  서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타   2023
# 16              3     폐업   서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식   2023
# 17              3     폐업          서울특별시 서초구 반포동 19-3 센트럴시티    기타   2023
# 19              3     폐업         서울특별시 강남구 대치동 889-65 우영빌딩    일식   2023
# 30              3     폐업           서울특별시 강동구 천호동 572 현대백화점    기타   2023
# ...           ...    ...                               ...   ...    ...
# 2098071         1  영업/정상       서울특별시 은평구 진관동 72 드림스퀘어 105호    분식   2020
# 2098072         1  영업/정상              서울특별시 은평구 진관동 296-12    한식   2020
# 2098073         1  영업/정상                서울특별시 은평구 대조동 68-2  출장조리   2020
# 2098198         1  영업/정상               서울특별시 광진구 광장동 322-6    기타   2020
# 2099441         1  영업/정상            서울특별시 강서구 화곡동 827-2 1층    한식   2020
#
#          인허가_월    폐업_년  폐업_월
# 11          12  2024.0   1.0
# 16           9  2024.0   1.0
# ...

# %%
seoul_df['영업상태구분코드'].value_counts()
# Out:
# 3    376581
# 1    125320
# Name: 영업상태구분코드, dtype: int64

# %%
seoul_df.loc[seoul_df['영업상태구분코드'] == 3, '영업상태구분코드'] = 2

# %%
seoul_df
# Out:
#          영업상태구분코드  영업상태명                           소재지전체주소 업태구분명  인허가_년  \
# 11              2     폐업  서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타   2023
# 16              2     폐업   서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식   2023
# 17              2     폐업          서울특별시 서초구 반포동 19-3 센트럴시티    기타   2023
# 19              2     폐업         서울특별시 강남구 대치동 889-65 우영빌딩    일식   2023
# 30              2     폐업           서울특별시 강동구 천호동 572 현대백화점    기타   2023
# ...           ...    ...                               ...   ...    ...
# 2098071         1  영업/정상       서울특별시 은평구 진관동 72 드림스퀘어 105호    분식   2020
# 2098072         1  영업/정상              서울특별시 은평구 진관동 296-12    한식   2020
# 2098073         1  영업/정상                서울특별시 은평구 대조동 68-2  출장조리   2020
# 2098198         1  영업/정상               서울특별시 광진구 광장동 322-6    기타   2020
# 2099441         1  영업/정상            서울특별시 강서구 화곡동 827-2 1층    한식   2020
#
#          인허가_월    폐업_년  폐업_월
# 11          12  2024.0   1.0
# 16           9  2024.0   1.0
# ...

# %%
# 구 추출
seoul_df['구'] = seoul_df['소재지전체주소'].str.split(' ').str[1]

# %%
seoul_df
# Out:
#          영업상태구분코드  영업상태명                           소재지전체주소 업태구분명  인허가_년  \
# 11              2     폐업  서울특별시 동대문구 전농동 591-53 청량리역,롯데백화점    기타   2023
# 16              2     폐업   서울특별시 강남구 논현동 221-7 한양수자인 어반게이트    한식   2023
# 17              2     폐업          서울특별시 서초구 반포동 19-3 센트럴시티    기타   2023
# 19              2     폐업         서울특별시 강남구 대치동 889-65 우영빌딩    일식   2023
# 30              2     폐업           서울특별시 강동구 천호동 572 현대백화점    기타   2023
# ...           ...    ...                               ...   ...    ...
# 2098071         1  영업/정상       서울특별시 은평구 진관동 72 드림스퀘어 105호    분식   2020
# 2098072         1  영업/정상              서울특별시 은평구 진관동 296-12    한식   2020
# 2098073         1  영업/정상                서울특별시 은평구 대조동 68-2  출장조리   2020
# 2098198         1  영업/정상               서울특별시 광진구 광장동 322-6    기타   2020
# 2099441         1  영업/정상            서울특별시 강서구 화곡동 827-2 1층    한식   2020
#
#          인허가_월    폐업_년  폐업_월     구
# 11          12  2024.0   1.0  동대문구
# ...

# %%
final_df = seoul_df.drop(columns={'소재지전체주소'})

# %%
final_df['인허가_년'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 501901 entries, 11 to 2099441
# Series name: 인허가_년
# Non-Null Count   Dtype
# --------------   -----
# 501901 non-null  int64
# dtypes: int64(1)
# memory usage: 7.7 MB

# %%
final_df['폐업_년'] = final_df['폐업_년'].astype('Int64')
final_df['폐업_월'] = final_df['폐업_월'].astype('Int64')

# %%
final_df
# Out:
#          영업상태구분코드  영업상태명 업태구분명  인허가_년  인허가_월  폐업_년  폐업_월     구
# 11              2     폐업    기타   2023     12  2024     1  동대문구
# 16              2     폐업    한식   2023      9  2024     1   강남구
# 17              2     폐업    기타   2023     11  2023    12   서초구
# 19              2     폐업    일식   2023     12  2023    12   강남구
# 30              2     폐업    기타   2023     11  2024     2   강동구
# ...           ...    ...   ...    ...    ...   ...   ...   ...
# 2098071         1  영업/정상    분식   2020      8  <NA>  <NA>   은평구
# 2098072         1  영업/정상    한식   2020      8  <NA>  <NA>   은평구
# 2098073         1  영업/정상  출장조리   2020      8  <NA>  <NA>   은평구
# 2098198         1  영업/정상    기타   2020      8  <NA>  <NA>   광진구
# 2099441         1  영업/정상    한식   2020      8  <NA>  <NA>   강서구
#
# [501901 rows x 8 columns]

# %%
final_df['업태구분명'].isna().sum()
# Out:
# 18

# %%
final_df['영업상태명'].isna().sum()
# Out:
# 0

# %%
# 업태구분명 결측치 '기타'로 대체
final_df['업태구분명'] = final_df['업태구분명'].fillna("기타")

# %%
final_df
# Out:
#          영업상태구분코드  영업상태명 업태구분명  인허가_년  인허가_월  폐업_년  폐업_월     구
# 11              2     폐업    기타   2023     12  2024     1  동대문구
# 16              2     폐업    한식   2023      9  2024     1   강남구
# 17              2     폐업    기타   2023     11  2023    12   서초구
# 19              2     폐업    일식   2023     12  2023    12   강남구
# 30              2     폐업    기타   2023     11  2024     2   강동구
# ...           ...    ...   ...    ...    ...   ...   ...   ...
# 2098071         1  영업/정상    분식   2020      8  <NA>  <NA>   은평구
# 2098072         1  영업/정상    한식   2020      8  <NA>  <NA>   은평구
# 2098073         1  영업/정상  출장조리   2020      8  <NA>  <NA>   은평구
# 2098198         1  영업/정상    기타   2020      8  <NA>  <NA>   광진구
# 2099441         1  영업/정상    한식   2020      8  <NA>  <NA>   강서구
#
# [501901 rows x 8 columns]

# %%
# 인덱스 재정렬
final_df = final_df.reset_index()

# %%
final_df = final_df.drop(columns={'index'})

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501901 entries, 0 to 501900
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   영업상태구분코드  501901 non-null  int64
#  1   영업상태명     501901 non-null  object
#  2   업태구분명     501901 non-null  object
#  3   인허가_년     501901 non-null  int64
#  4   인허가_월     501901 non-null  int64
#  5   폐업_년      376577 non-null  Int64
#  6   폐업_월      376577 non-null  Int64
#  7   구         501901 non-null  object
# dtypes: Int64(2), int64(3), object(3)
# memory usage: 31.6+ MB

# %%
# csv 파일로 저장
# final_df.to_csv('일반음식점_인허가정보.csv', index=False)

# %%
final_df['구'].value_counts()
# Out:
# 강남구     47407
# 송파구     28922
# 마포구     27303
# 서초구     26036
# 영등포구    26011
# 강동구     22131
# 강서구     21996
# 관악구     21727
# 중구      20964
# 동대문구    20844
# 종로구     19522
# 구로구     18651
# 서대문구    17210
# 성북구     17137
# 광진구     17089
# 양천구     16908
# 중랑구     16786
# 은평구     16573
# 강북구     16121
# 노원구     15173
# 용산구     15138
# 성동구     13993
# 동작구     13700
# 금천구     13076
# 도봉구     11483
# Name: 구, dtype: int64

# %%
영업_df = final_df[final_df['영업상태구분코드']==1]

# %%
영업_df
# Out:
#         영업상태구분코드  영업상태명 업태구분명  인허가_년  인허가_월  폐업_년  폐업_월    구
# 376581         1  영업/정상    기타   2023     11  <NA>  <NA>  마포구
# 376582         1  영업/정상    기타   2023     11  <NA>  <NA>  마포구
# 376583         1  영업/정상    기타   2023     11  <NA>  <NA>  마포구
# 376584         1  영업/정상    기타   2023     11  <NA>  <NA>  마포구
# 376585         1  영업/정상    한식   2023     11  <NA>  <NA>  강북구
# ...          ...    ...   ...    ...    ...   ...   ...  ...
# 501896         1  영업/정상    분식   2020      8  <NA>  <NA>  은평구
# 501897         1  영업/정상    한식   2020      8  <NA>  <NA>  은평구
# 501898         1  영업/정상  출장조리   2020      8  <NA>  <NA>  은평구
# 501899         1  영업/정상    기타   2020      8  <NA>  <NA>  광진구
# 501900         1  영업/정상    한식   2020      8  <NA>  <NA>  강서구
#
# [125320 rows x 8 columns]

# %%
영업_df['구'].value_counts()
# Out:
# 강남구     12503
# 마포구      8493
# 송파구      7420
# 종로구      7237
# 영등포구     6882
# 강서구      6278
# 중구       5992
# 서초구      5760
# 용산구      5112
# 관악구      4876
# 광진구      4274
# 동대문구     4244
# 구로구      4132
# 성동구      4019
# 성북구      4001
# 강동구      3963
# 중랑구      3846
# 은평구      3827
# 노원구      3709
# 서대문구     3535
# 강북구      3419
# 동작구      3241
# 양천구      3141
# 금천구      3121
# 도봉구      2295
# Name: 구, dtype: int64

# %%
영업_df['업태구분명'].value_counts()
# Out:
# 한식                 52907
# 기타                 20989
# 호프/통닭               9858
# 경양식                 9453
# 분식                  8517
# 일식                  6692
# 중국식                 4879
# 통닭(치킨)              2106
# 정종/대포집/소주방          2047
# 외국음식전문점(인도,태국등)     1758
# 까페                  1689
# 식육(숯불구이)            1031
# 패스트푸드                585
# 횟집                   550
# 김밥(도시락)              545
# 뷔페식                  450
# 감성주점                 300
# 라이브카페                207
# 패밀리레스트랑              203
# 냉면집                  160
# 탕류(보신용)              138
# 출장조리                 102
# 전통찻집                  53
# 복어취급                  50
# 키즈카페                  46
# 이동조리                   3
# 커피숍                    2
# Name: 업태구분명, dtype: int64

# %% [markdown]
# # Hive에서 정제된 일반음식점 + 커피수입량 합치기

# %%
df_normal = pd.read_csv("일반음식점_정제.csv")

# %%
df_normal
# Out:
#     year  month  opened  closed
# 0   2021      1     977     772
# 1   2021      2    1015     745
# 2   2021      3    1297    1026
# 3   2021      4    1399    1339
# 4   2021      5    1215    1405
# 5   2021      6    1250    1044
# 6   2021      7    1183    1105
# 7   2021      8    1059    1008
# 8   2021      9     988    1062
# 9   2021     10    1041     873
# 10  2021     11    1170    1247
# 11  2021     12     964    1249
# 12  2022      1     830     675
# 13  2022      2     794    1035
# 14  2022      3    1089     935
# 15  2022      4    1164     870
# 16  2022      5    1136     908
# 17  2022      6    1203    1388
# 18  2022      7    1049    1089
# 19  2022      8    1101    1081
# 20  2022      9    1049    1028
# 21  2022     10    1081    1043
# 22  2022     11    1225    1180
# 23  2022     12    1049    1461
# 24  2023      1     989    1041
# 25  2023      2    1079     936
# 26  2023      3    1380    1316
# 27  2023      4    1267    1226
# ...

# %%
df_coffee = pd.read_csv("/content/drive/MyDrive/최종_년월_원두수입량.csv")

# %%
df_coffee
# Out:
#     year  month    당월-수입-중량
# 0   2021      1  14514756.9
# 1   2021      2  12270612.6
# 2   2021      3  16624291.0
# 3   2021      4  16798904.7
# 4   2021      5  15322855.7
# 5   2021      6  17241103.7
# 6   2021      7  14234081.0
# 7   2021      8  14597497.2
# 8   2021      9  12620690.4
# 9   2021     10  15238692.4
# 10  2021     11  18954359.0
# 11  2021     12  17395523.9
# 12  2022      1  12081690.7
# 13  2022      2  12729612.7
# 14  2022      3  19128983.4
# 15  2022      4  17213844.5
# 16  2022      5  16751290.4
# 17  2022      6  14349033.3
# 18  2022      7  20778525.4
# 19  2022      8  20667036.6
# 20  2022      9  17332397.4
# 21  2022     10  18530744.3
# 22  2022     11  16737582.0
# 23  2022     12  16911182.8
# 24  2023      1  14621088.4
# 25  2023      2  13535042.5
# 26  2023      3  14221566.0
# 27  2023      4  14305549.8
# 28  2023      5  16087815.9
# 29  2023      6  16528421.9
# 30  2023      7  16323101.9
# 31  2023      8  15302556.8
# ...

# %%
df_linear = pd.concat([df_normal, df_coffee['당월-수입-중량']],axis=1)

# %%
df_linear
# Out:
#     year  month  opened  closed    당월-수입-중량
# 0   2021      1     977     772  14514756.9
# 1   2021      2    1015     745  12270612.6
# 2   2021      3    1297    1026  16624291.0
# 3   2021      4    1399    1339  16798904.7
# 4   2021      5    1215    1405  15322855.7
# 5   2021      6    1250    1044  17241103.7
# 6   2021      7    1183    1105  14234081.0
# 7   2021      8    1059    1008  14597497.2
# 8   2021      9     988    1062  12620690.4
# 9   2021     10    1041     873  15238692.4
# 10  2021     11    1170    1247  18954359.0
# 11  2021     12     964    1249  17395523.9
# 12  2022      1     830     675  12081690.7
# 13  2022      2     794    1035  12729612.7
# 14  2022      3    1089     935  19128983.4
# 15  2022      4    1164     870  17213844.5
# 16  2022      5    1136     908  16751290.4
# 17  2022      6    1203    1388  14349033.3
# 18  2022      7    1049    1089  20778525.4
# 19  2022      8    1101    1081  20667036.6
# ...

# %%
df_linear.rename(columns = {'당월-수입-중량' : 'coffee'}, inplace = True)

# %%
df_linear
# Out:
#     year  month  opened  closed      coffee
# 0   2021      1     977     772  14514756.9
# 1   2021      2    1015     745  12270612.6
# 2   2021      3    1297    1026  16624291.0
# 3   2021      4    1399    1339  16798904.7
# 4   2021      5    1215    1405  15322855.7
# 5   2021      6    1250    1044  17241103.7
# 6   2021      7    1183    1105  14234081.0
# 7   2021      8    1059    1008  14597497.2
# 8   2021      9     988    1062  12620690.4
# 9   2021     10    1041     873  15238692.4
# 10  2021     11    1170    1247  18954359.0
# 11  2021     12     964    1249  17395523.9
# 12  2022      1     830     675  12081690.7
# 13  2022      2     794    1035  12729612.7
# 14  2022      3    1089     935  19128983.4
# 15  2022      4    1164     870  17213844.5
# 16  2022      5    1136     908  16751290.4
# 17  2022      6    1203    1388  14349033.3
# 18  2022      7    1049    1089  20778525.4
# 19  2022      8    1101    1081  20667036.6
# ...

# %%
df_linear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    36 non-null     int64
#  1   month   36 non-null     int64
#  2   opened  36 non-null     int64
#  3   closed  36 non-null     int64
#  4   coffee  36 non-null     float64
# dtypes: float64(1), int64(4)
# memory usage: 1.5 KB

# %%
df_linear['년월'] = df_linear['year'].astype(str)+"년 "+df_linear['month'].astype(str)+"월"

# %%
df_linear
# Out:
#     year  month  opened  closed      coffee         년월
# 0   2021      1     977     772  14514756.9   2021년 1월
# 1   2021      2    1015     745  12270612.6   2021년 2월
# 2   2021      3    1297    1026  16624291.0   2021년 3월
# 3   2021      4    1399    1339  16798904.7   2021년 4월
# 4   2021      5    1215    1405  15322855.7   2021년 5월
# 5   2021      6    1250    1044  17241103.7   2021년 6월
# 6   2021      7    1183    1105  14234081.0   2021년 7월
# 7   2021      8    1059    1008  14597497.2   2021년 8월
# 8   2021      9     988    1062  12620690.4   2021년 9월
# 9   2021     10    1041     873  15238692.4  2021년 10월
# 10  2021     11    1170    1247  18954359.0  2021년 11월
# 11  2021     12     964    1249  17395523.9  2021년 12월
# 12  2022      1     830     675  12081690.7   2022년 1월
# 13  2022      2     794    1035  12729612.7   2022년 2월
# 14  2022      3    1089     935  19128983.4   2022년 3월
# 15  2022      4    1164     870  17213844.5   2022년 4월
# ...

# %%
df_linear = df_linear.drop(columns={'year','month'})

# %%
df_linear
# Out:
#     opened  closed      coffee         년월
# 0      977     772  14514756.9   2021년 1월
# 1     1015     745  12270612.6   2021년 2월
# 2     1297    1026  16624291.0   2021년 3월
# 3     1399    1339  16798904.7   2021년 4월
# 4     1215    1405  15322855.7   2021년 5월
# 5     1250    1044  17241103.7   2021년 6월
# 6     1183    1105  14234081.0   2021년 7월
# 7     1059    1008  14597497.2   2021년 8월
# 8      988    1062  12620690.4   2021년 9월
# 9     1041     873  15238692.4  2021년 10월
# 10    1170    1247  18954359.0  2021년 11월
# 11     964    1249  17395523.9  2021년 12월
# 12     830     675  12081690.7   2022년 1월
# 13     794    1035  12729612.7   2022년 2월
# 14    1089     935  19128983.4   2022년 3월
# 15    1164     870  17213844.5   2022년 4월
# 16    1136     908  16751290.4   2022년 5월
# 17    1203    1388  14349033.3   2022년 6월
# 18    1049    1089  20778525.4   2022년 7월
# 19    1101    1081  20667036.6   2022년 8월
# 20    1049    1028  17332397.4   2022년 9월
# ...

# %%
df_linear.set_index('년월', inplace=True)

# %% [markdown]
# # 일반음식점 개폐업 정보 시계열 시각화

# %%
#!apt-get install fonts-nanum* -qq

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 39 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()
sys_font[0]
# Out:
# '/usr/share/fonts/truetype/nanum/NanumBrush.ttf'

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

# %%
# 그래프 플로팅
df_linear.plot(figsize=(10, 6))

# 그래프 제목 및 레이블 추가
plt.title('커피 소비량과 음식점 개폐업 변화')
plt.xlabel('년월')
plt.ylabel('변화량')

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()

# %% [markdown]
# # StandardScaler

# %%
# StandardScaler를 사용하여 열을 표준화
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
scaled_values = scaler.fit_transform(df_linear.values)

# MinMaxScaler를 사용하여 표준화된 데이터를 정규화
min_max_scaler = MinMaxScaler()
normalized_values = min_max_scaler.fit_transform(scaled_values)
df_final = pd.DataFrame(normalized_values, index=df_linear.index, columns=df_linear.columns)

df_final
# Out:
#              opened    closed    coffee
# 년월
# 2021년 1월   0.302479  0.123410  0.279765
# 2021년 2월   0.365289  0.089059  0.021723
# 2021년 3월   0.831405  0.446565  0.522328
# 2021년 4월   1.000000  0.844784  0.542406
# 2021년 5월   0.695868  0.928753  0.372683
# 2021년 6월   0.753719  0.469466  0.593252
# 2021년 7월   0.642975  0.547074  0.247491
# 2021년 8월   0.438017  0.423664  0.289278
# 2021년 9월   0.320661  0.492366  0.061977
# 2021년 10월  0.408264  0.251908  0.363006
# 2021년 11월  0.621488  0.727735  0.790249
# 2021년 12월  0.280992  0.730280  0.611008
# 2022년 1월   0.059504  0.000000  0.000000
# 2022년 2월   0.000000  0.458015  0.074501
# 2022년 3월   0.487603  0.330789  0.810328
# 2022년 4월   0.611570  0.248092  0.590117
# 2022년 5월   0.565289  0.296438  0.536931
# 2022년 6월   0.676033  0.907125  0.260709
# 2022년 7월   0.421488  0.526718  1.000000
# 2022년 8월   0.507438  0.516539  0.987181
# 2022년 9월   0.421488  0.449109  0.603749
# 2022년 10월  0.474380  0.468193  0.741540
# ...

# %%
df_final.rename(columns = {'opened' : '개업','closed':'폐업'}, inplace = True)

# %%
# 그래프 플로팅
plt.figure(figsize=(20, 6))

# seaborn의 barplot() 함수를 사용하여 커피 수입량 시각화
sns.barplot(data=df_final, x='년월', y='coffee', color='skyblue', label='커피수입량')

# pandas의 plot() 함수를 사용하여 개업 및 폐업량 시계열 그래프 시각화
df_final[['개업', '폐업']].plot(ax=plt.gca(), color=['orange', 'green'])

# 그래프 제목 및 레이블 추가
plt.title('커피 수입량과 음식점 개폐업 변화')
plt.xlabel('년월')
plt.ylabel('변화량')

# x축 눈금 각도 설정
plt.xticks(rotation=45)

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()

# %%
# 그래프를 이미지로 저장
plt.savefig('커피 수입량과 음식점 개폐업 변화.png')

# %% [markdown]
# # 자치구별 사업체 수 시각화

# %%
df_company = pd.read_csv("/content/drive/MyDrive/서울시사업체조사결과정보(2022년)/2022년 기준 사업체조사.csv")

# %%
df_company
# Out:
#          SURV_BASE_YEAR     AD_CD  RPRS_SD_CD  RPRS_GNR  FND_YEAR  FND_MM  \
# 0                  2022  11240650           2         6      2020       6
# 1                  2022  11180570           1         5      2020       6
# 2                  2022  11250730           1         5      2009      11
# 3                  2022  11220670           2         3      2016       3
# 4                  2022  11220610           1         5      2020       5
# ...                 ...       ...         ...       ...       ...     ...
# 1180020            2022  11200720           1         7      2010       6
# 1180021            2022  11030530           1         6      2020       6
# 1180022            2022  11200710           1         5      2017       7
# 1180023            2022  11200710           1         6      2020       6
# 1180024            2022  11110790           1         4      2017       6
#
#          ORG_FORM_CD  ESTM_DIV_CD INDST_LCLS_CD  MBZ_INDST_DIV_CD  ...  \
# ...

# %%
df_company.columns
# Out:
# Index(['SURV_BASE_YEAR', 'AD_CD', 'RPRS_SD_CD', 'RPRS_GNR', 'FND_YEAR',
#        'FND_MM', 'ORG_FORM_CD', 'ESTM_DIV_CD', 'INDST_LCLS_CD',
#        'MBZ_INDST_DIV_CD', 'SURV_PHS_SLFM_SUM', 'SURV_PHS_SLFM_MAN_CNT',
#        'SURV_PHS_SLFM_WMAN_CNT', 'SURV_PHS_UPF_SUM', 'SURV_PHS_UPF_MAN_CNT',
#        'SURV_PHS_UPF_WMAN_CNT', 'SURV_PHS_CE_SUM', 'SURV_PHS_CE_MAN_CNT',
#        'SURV_PHS_CE_WMAN_CNT', 'SURV_PHS_TMPR_DALY_SUM',
#        'SURV_PHS_TMPR_DALY_MAN_CNT', 'SURV_PHS_TMPR_DALY_WMAN_CNT',
#        'SURV_PHS_OTR_SUM', 'SURV_PHS_OTR_MAN_CNT', 'SURV_PHS_OTR_WMAN_CNT',
#        'SURV_PHS_WOKE_SUM', 'SURV_PHS_MAN_SUM', 'SURV_PHS_WMAN_SUM'],
#       dtype='object')

# %%
df_company = df_company.drop(columns={'SURV_BASE_YEAR','RPRS_SD_CD', 'RPRS_GNR', 'FND_YEAR',
       'FND_MM','INDST_LCLS_CD',
       'MBZ_INDST_DIV_CD', 'SURV_PHS_SLFM_SUM', 'SURV_PHS_SLFM_MAN_CNT',
       'SURV_PHS_SLFM_WMAN_CNT', 'SURV_PHS_UPF_SUM', 'SURV_PHS_UPF_MAN_CNT',
       'SURV_PHS_UPF_WMAN_CNT', 'SURV_PHS_CE_SUM', 'SURV_PHS_CE_MAN_CNT',
       'SURV_PHS_CE_WMAN_CNT', 'SURV_PHS_TMPR_DALY_SUM',
       'SURV_PHS_TMPR_DALY_MAN_CNT', 'SURV_PHS_TMPR_DALY_WMAN_CNT',
       'SURV_PHS_OTR_SUM', 'SURV_PHS_OTR_MAN_CNT', 'SURV_PHS_OTR_WMAN_CNT',
      'SURV_PHS_MAN_SUM', 'SURV_PHS_WMAN_SUM'})

# %%
df_company
# Out:
#             AD_CD  ORG_FORM_CD  ESTM_DIV_CD  SURV_PHS_WOKE_SUM
# 0        11240650            1            1                  1
# 1        11180570            1            1                  7
# 2        11250730            1            1                  1
# 3        11220670            2            1                  1
# 4        11220610            2            1                  3
# ...           ...          ...          ...                ...
# 1180020  11200720            2            3                  7
# 1180021  11030530            2            3                  4
# 1180022  11200710            1            1                  1
# 1180023  11200710            2            3                  1
# 1180024  11110790            1            1                  4
#
# [1180025 rows x 4 columns]

# %%
df_company.rename(columns={'AD_CD': '행정구역코드', 'ORG_FORM_CD': '조직형태','ESTM_DIV_CD':'사업체구분','SURV_PHS_WOKE_SUM':'종사자수_합계'}, inplace=True)

# %%
df_company
# Out:
#            행정구역코드  조직형태  사업체구분  종사자수_합계
# 0        11240650     1      1        1
# 1        11180570     1      1        7
# 2        11250730     1      1        1
# 3        11220670     2      1        1
# 4        11220610     2      1        3
# ...           ...   ...    ...      ...
# 1180020  11200720     2      3        7
# 1180021  11030530     2      3        4
# 1180022  11200710     1      1        1
# 1180023  11200710     2      3        1
# 1180024  11110790     1      1        4
#
# [1180025 rows x 4 columns]

# %%
df_company_sum = df_company.groupby('행정구역코드').sum('종사자수_합계')

# %%
df_company_sum
# Out:
#           조직형태  사업체구분  종사자수_합계
# 행정구역코드
# 11010530  8185   6031    56046
# 11010540  1448   1239     5118
# 11010550  1251    991     4140
# 11010560  1812   1431     4294
# 11010570   990    875     1987
# ...        ...    ...      ...
# 11250730  5939   5576    16059
# 11250740  7885   6975    20017
# 11250750  1979   1687     4963
# 11250760  2134   1897     7197
# 11250770   746    641    19974
#
# [426 rows x 3 columns]

# %%
df_company_sum = df_company_sum.drop(columns={'조직형태','사업체구분'})

# %%
df_company_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426 entries, 11010530 to 11250770
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   종사자수_합계  426 non-null    int64
# dtypes: int64(1)
# memory usage: 6.7 KB

# %%
df_company_sum = df_company_sum.reset_index()

# %%
df_company_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   행정구역코드   426 non-null    int64
#  1   종사자수_합계  426 non-null    int64
# dtypes: int64(2)
# memory usage: 6.8 KB

# %%
df_company_sum['행정구코드'] = df_company_sum['행정구역코드'] // 1000

# %%
df_company_sum = df_company_sum.drop(columns={'행정구역코드'})

# %%
df_company_sum
# Out:
#      종사자수_합계  행정구코드
# 0      56046  11010
# 1       5118  11010
# 2       4140  11010
# 3       4294  11010
# 4       1987  11010
# ..       ...    ...
# 421    16059  11250
# 422    20017  11250
# 423     4963  11250
# 424     7197  11250
# 425    19974  11250
#
# [426 rows x 2 columns]

# %%
df_company_sum = df_company_sum.groupby(['행정구코드']).sum('종사자수_합계')

# %%
df_company_sum
# Out:
#        종사자수_합계
# 행정구코드
# 11010   278403
# 11020   386148
# 11030   151851
# 11040   205900
# 11050   129917
# 11060   145879
# 11070   114733
# 11080   125727
# 11090    79859
# 11100    77618
# 11110   129198
# 11120   107697
# 11130   119608
# 11140   274678
# 11150   133815
# 11160   299324
# 11170   242640
# 11180   256316
# 11190   433237
# 11200   107069
# 11210   126395
# 11220   492367
# 11230   802908
# 11240   409305
# 11250   164833

# %%
df_company_sum.index
# Out:
# Int64Index([11010, 11020, 11030, 11040, 11050, 11060, 11070, 11080, 11090,
#             11100, 11110, 11120, 11130, 11140, 11150, 11160, 11170, 11180,
#             11190, 11200, 11210, 11220, 11230, 11240, 11250],
#            dtype='int64', name='행정구코드')

# %%
df_company_sum['행정구'] = ['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구',
                         '도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구',
                         '금천구','영등포구','동작구','관악구','서초구','강남구','송파구','강동구']

# %%
df_company_sum
# Out:
#        종사자수_합계   행정구
# 행정구코드
# 11010   278403   종로구
# 11020   386148    중구
# 11030   151851   용산구
# 11040   205900   성동구
# 11050   129917   광진구
# 11060   145879  동대문구
# 11070   114733   중랑구
# 11080   125727   성북구
# 11090    79859   강북구
# 11100    77618   도봉구
# 11110   129198   노원구
# 11120   107697   은평구
# 11130   119608  서대문구
# 11140   274678   마포구
# 11150   133815   양천구
# 11160   299324   강서구
# 11170   242640   구로구
# 11180   256316   금천구
# 11190   433237  영등포구
# 11200   107069   동작구
# 11210   126395   관악구
# 11220   492367   서초구
# 11230   802908   강남구
# 11240   409305   송파구
# 11250   164833   강동구

# %%
# '종사자수_합계' 열을 기준으로 DataFrame 정렬
df_company_sum_sorted = df_company_sum.sort_values(by='종사자수_합계', ascending=False)

# 정렬된 DataFrame 출력
df_company_sum_sorted
# Out:
#        종사자수_합계   행정구
# 행정구코드
# 11230   802908   강남구
# 11220   492367   서초구
# 11190   433237  영등포구
# 11240   409305   송파구
# 11020   386148    중구
# 11160   299324   강서구
# 11010   278403   종로구
# 11140   274678   마포구
# 11180   256316   금천구
# 11170   242640   구로구
# 11040   205900   성동구
# 11250   164833   강동구
# 11030   151851   용산구
# 11060   145879  동대문구
# 11150   133815   양천구
# 11050   129917   광진구
# 11110   129198   노원구
# 11210   126395   관악구
# 11080   125727   성북구
# 11130   119608  서대문구
# 11070   114733   중랑구
# 11120   107697   은평구
# 11200   107069   동작구
# 11090    79859   강북구
# 11100    77618   도봉구

# %%
# 그래프 플로팅
plt.figure(figsize=(20, 6))

# seaborn의 barplot() 함수를 사용하여 커피 수입량 시각화
sns.barplot(data=df_company_sum_sorted.head(5), x='행정구', y='종사자수_합계')


# 그래프 제목 및 레이블 추가
plt.title('행정구별 종사자수 합계')
# Out:
# Text(0.5, 1.0, '행정구별 종사자수 합계')
