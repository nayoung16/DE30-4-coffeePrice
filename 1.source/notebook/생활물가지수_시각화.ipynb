# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/생활물가지수_2020100__20240313145426 - 시트2.csv')

# %%
df.head()
# Out:
#        품목별     총지수  생활물가지수      식품        쌀 국수       라면      두부       빵  \
# 0  2019.01  98.884  98.644  96.626  100.411  -  100.033  95.819  94.833
# 1  2019.02  99.311  99.194  97.105  100.258  -   99.489  96.779  94.974
# 2  2019.03  99.121  99.042  96.599  100.216  -  100.138  97.603  96.785
# 3  2019.04  99.481  99.384  97.070   99.435  -   99.136  97.972  98.721
# 4  2019.05  99.652  99.839  96.972   99.698  -  100.635  98.224  98.862
#
#         떡  ...      김밥     떡볶이      치킨      햄버거       피자  커피(외식)  기타음료(외식)  \
# 0  96.439  ...  95.668  96.224  97.065  100.860  100.725  99.192         -
# 1  97.270  ...  96.109  96.592  97.281  101.196  100.725  99.269         -
# 2  97.602  ...  96.550  96.961  98.012  101.196  100.725  99.900         -
# 3  97.891  ...  96.758  96.961  98.355  101.196  100.725  99.919         -
# 4  97.681  ...  96.959  97.129  98.869  101.196  100.725  99.939         -
#
#    소주(외식)  맥주(외식)  구내식당식사비
# 0  98.772  97.786   95.753
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.plot(df['품목별'], df['총지수'])
plt.xlim([2019.01,2019.12])
# Out:
# (2019.01, 2019.12)

# %%
df.columns
# Out:
# Index(['품목별', '총지수', '생활물가지수', '식품', '쌀', '국수', '라면', '두부', '빵', '떡', '국산쇠고기',
#        '수입쇠고기', '돼지고기', '닭고기', '햄및베이컨', '기타육류가공품', '고등어', '오징어', '조개', '어묵',
#        '우유', '발효유', '달걀', '참기름', '식용유', '사과', '포도', '귤', '수박', '바나나', '배추',
#        '상추', '시금치', '깻잎', '부추', '무', '당근', '감자', '콩나물', '버섯', '오이', '풋고추',
#        '호박', '토마토', '파', '양파', '마늘', '김', '사탕', '아이스크림', '비스킷', '스낵과자', '파이',
#        '소금', '간장', '밑반찬', '냉동식품', '즉석식품', '편의점도시락', '삼각김밥', '커피', '주스', '두유',
#        '생수', '탄산음료', '소주', '맥주', '막걸리', '김치찌개백반', '된장찌개백반', '비빔밥', '해장국',
#        '돼지갈비(외식)', '삼겹살(외식)', '냉면', '칼국수', '자장면', '짬뽕', '김밥', '떡볶이', '치킨',
#        '햄버거', '피자', '커피(외식)', '기타음료(외식)', '소주(외식)', '맥주(외식)', '구내식당식사비'],
#       dtype='object')

# %%
selected_columns = ['쌀', '국수', '라면', '두부', '빵', '떡', '국산쇠고기',
       '수입쇠고기', '돼지고기', '닭고기', '햄및베이컨', '기타육류가공품','커피']

# %%
# !apt-get install fonts-nanum* -qq
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Setting up fonts-nanum-coding (2.5-3) ...
# Setting up fonts-nanum-eco (1.000-7) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# ...

# %%
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()
sys_font[0]
# Out:
# '/usr/share/fonts/truetype/nanum/NanumPen.ttf'

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
for column in selected_columns:
  sns.lineplot(df,x='품목별', y=column, label=column)
plt.legend(loc='upper right')  # 범례를 오른쪽 끝에 배치
plt.ylim(0,150)
plt.show()

# %%
selected_columns2 = ['고등어', '오징어', '조개', '어묵','우유', '발효유', '달걀', '참기름', '식용유','커피']

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
for column in selected_columns2:
  sns.lineplot(df,x='품목별', y=column, label=column)
plt.legend(loc='upper right')  # 범례를 오른쪽 끝에 배치
plt.ylim(60,200)
plt.show()

# %%
selected_columns3 = ['사과', '포도', '귤', '수박', '바나나', '배추',
       '상추', '시금치', '깻잎', '부추', '무', '당근', '감자', '콩나물', '버섯', '오이', '풋고추','커피']

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
for column in selected_columns3:
  sns.lineplot(df,x='품목별', y=column, label=column)
plt.legend(loc='upper right')  # 범례를 오른쪽 끝에 배치
plt.ylim(0,300)
plt.show()

# %%
# 커피 물가 시각화
plt.figure(figsize=(10,5))
sns.lineplot(df,x='품목별', y='커피', label='커피')
plt.legend(loc='upper right')  # 범례를 오른쪽 끝에 배치
plt.show()

# %%
# 전체 품목과 커피와의 생활물가지수 비교
for column in df.columns:
  plt.figure(figsize=(10,5))
  sns.lineplot(df,x='품목별', y=column, label=column)
  sns.lineplot(df,x='품목별', y='커피', label='커피')
  plt.legend(loc='upper right')  # 범례를 오른쪽 끝에 배치
  plt.ylim(0,300)
  plt.show()
